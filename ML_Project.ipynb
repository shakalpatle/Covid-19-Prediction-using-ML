# %% [markdown]
# <a href="https://colab.research.google.com/github/shakalpatle/Covid-19-Prediction-using-ML/blob/main/ML_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# %%
corona_df = pd.read_csv('/content/covid_19_data.csv', parse_dates=['Last Update'])

# %%
# s = corona_df = pd.read_csv('/content/covid_19_data.csv')

# %%
# s.describe()

# %%
# s.head()

# %%
# Earliest Cases
corona_df.head()

# # Latest Cases
# corona_df.tail()
# Out:
#    SNo ObservationDate Province/State  Country/Region         Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China 2020-01-22 17:00:00
# 1    2      01/22/2020        Beijing  Mainland China 2020-01-22 17:00:00
# 2    3      01/22/2020      Chongqing  Mainland China 2020-01-22 17:00:00
# 3    4      01/22/2020         Fujian  Mainland China 2020-01-22 17:00:00
# 4    5      01/22/2020          Gansu  Mainland China 2020-01-22 17:00:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
corona_df.tail()
# Out:
#          SNo ObservationDate Province/State  Country/Region  \
# 15126  15127      04/14/2020        Wyoming              US
# 15127  15128      04/14/2020       Xinjiang  Mainland China
# 15128  15129      04/14/2020          Yukon          Canada
# 15129  15130      04/14/2020         Yunnan  Mainland China
# 15130  15131      04/14/2020       Zhejiang  Mainland China
#
#               Last Update  Confirmed  Deaths  Recovered
# 15126 2020-04-14 23:41:11      282.0     1.0        0.0
# 15127 2020-04-14 23:41:11       76.0     3.0       73.0
# 15128 2020-04-14 23:41:11        8.0     0.0        0.0
# 15129 2020-04-14 23:41:11      184.0     2.0      175.0
# 15130 2020-04-14 23:41:11     1267.0     1.0     1242.0

# %%
corona_df.describe()
# Out:
#                 SNo      Confirmed        Deaths     Recovered
# count  15131.000000   15131.000000  15131.000000  15131.000000
# mean    7566.000000    2061.836759    108.210165    502.725530
# std     4368.087797   11189.202681    913.498994   4117.613616
# min        1.000000       0.000000      0.000000      0.000000
# 25%     3783.500000       6.000000      0.000000      0.000000
# 50%     7566.000000      72.000000      1.000000      1.000000
# 75%    11348.500000     481.000000      5.000000     37.000000
# max    15131.000000  203020.000000  21067.000000  68200.000000

# %%
####################################
## Data Transformation            ##
# ##################################
# renaming ObservationDate to Date and Country/Region to Country.
corona_df.rename(columns={'ObservationDate': 'Date',
                          'Country/Region': 'Country'}, inplace=True)

# %%
# Here, I am verifying the datatype of the corona_df. Before making the model,
# all the independent variables should be in the numerical format except date.
corona_df.dtypes
# Out:
# SNo                        int64
# Date                      object
# Province/State            object
# Country                   object
# Last Update       datetime64[ns]
# Confirmed                float64
# Deaths                   float64
# Recovered                float64
# dtype: object

# %%
corona_df.shape
# Out:
# (15131, 8)

# %%
corona_df.isnull()
# Out:
#          SNo   Date  Province/State  Country  Last Update  Confirmed  Deaths  \
# 0      False  False           False    False        False      False   False
# 1      False  False           False    False        False      False   False
# 2      False  False           False    False        False      False   False
# 3      False  False           False    False        False      False   False
# 4      False  False           False    False        False      False   False
# ...      ...    ...             ...      ...          ...        ...     ...
# 15126  False  False           False    False        False      False   False
# 15127  False  False           False    False        False      False   False
# 15128  False  False           False    False        False      False   False
# 15129  False  False           False    False        False      False   False
# 15130  False  False           False    False        False      False   False
#
#        Recovered
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ...          ...
# 15126      False
# 15127      False
# 15128      False
# 15129      False
# 15130      False
#
# [15131 rows x 8 columns]

# %%
# Normalize the data.
# Here, I am checking any null values in any columns. If there are, I need to replace those values.
# Only Province column has the null values.
corona_df.isnull().sum().to_frame('nulls')
corona_df["Province/State"].fillna("NA", inplace=True)

# %%
corona_df.describe()
# Out:
#                 SNo      Confirmed        Deaths     Recovered
# count  15131.000000   15131.000000  15131.000000  15131.000000
# mean    7566.000000    2061.836759    108.210165    502.725530
# std     4368.087797   11189.202681    913.498994   4117.613616
# min        1.000000       0.000000      0.000000      0.000000
# 25%     3783.500000       6.000000      0.000000      0.000000
# 50%     7566.000000      72.000000      1.000000      1.000000
# 75%    11348.500000     481.000000      5.000000     37.000000
# max    15131.000000  203020.000000  21067.000000  68200.000000

# %%
## Exploratory Analysis           ##
# ##################################
# Let's get the total Confirmed, Deaths and Recovered cases in the world(till 04/14).

# Here, I have done groupby date and country.
corona_df = corona_df.groupby(["Date", "Country"])[
    ['Date', 'Country', 'Confirmed', 'Deaths', 'Recovered']].sum().reset_index()
corona_sorted_df = corona_df.sort_values('Date', ascending=False)
corona_sorted_df = corona_sorted_df.drop_duplicates('Country')

# Now, I have all the unique date in the date column with country.
corona_sorted_df.head(80)
# Out:
#             Date              Country  Confirmed  Deaths  Recovered
# 8108  04/14/2020             Zimbabwe       17.0     3.0        0.0
# 7980  04/14/2020              Finland     3161.0    64.0      300.0
# 7989  04/14/2020            Guatemala      167.0     5.0       19.0
# 7988  04/14/2020              Grenada       14.0     0.0        0.0
# 7987  04/14/2020               Greece     2170.0   101.0      269.0
# ...          ...                  ...        ...     ...        ...
# 7963  04/14/2020                 Cuba      766.0    21.0      132.0
# 7962  04/14/2020              Croatia     1704.0    31.0      415.0
# 7961  04/14/2020           Costa Rica      618.0     3.0       66.0
# 7960  04/14/2020     Congo (Kinshasa)      241.0    20.0       20.0
# 7959  04/14/2020  Congo (Brazzaville)       60.0     5.0        5.0
#
# [80 rows x 5 columns]

# %%
corona_confirmed_total_df = corona_sorted_df['Confirmed'].sum()
corona_deaths_total_df = corona_sorted_df['Deaths'].sum()
corona_recovered_total_df = corona_sorted_df['Recovered'].sum()

corona_confirmed_total_df = round(corona_confirmed_total_df, 2)
corona_deaths_total_df = round(corona_deaths_total_df, 2)
corona_recovered_total_df = round(corona_recovered_total_df, 2)

# %%
corona_dict = {'Total Confirmed cases  in the world': corona_confirmed_total_df,
               'Total Deaths cases in the world': corona_deaths_total_df, 'Total Recovered cases in the world': corona_recovered_total_df}
corona_dict = pd.DataFrame.from_dict(
    corona_dict, orient='index', columns=['Total'])

corona_dict.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_20c56_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_20c56_row1_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_20c56_row2_col0 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# </style>
# <table id="T_20c56_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20c56_level0_row0" class="row_heading level0 row0" >Total Confirmed cases  in the world</th>
#       <td id="T_20c56_row0_col0" class="data row0 col0" >1977127.000000</td>
#     </tr>
#     <tr>
#       <th id="T_20c56_level0_row1" class="row_heading level0 row1" >Total Deaths cases in the world</th>
#       <td id="T_20c56_row1_col0" class="data row1 col0" >125994.000000</td>
#     </tr>
#     <tr>
#       <th id="T_20c56_level0_row2" class="row_heading level0 row2" >Total Recovered cases in the world</th>
#       <td id="T_20c56_row2_col0" class="data row2 col0" >474835.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Graphic illustrates Total cases in the world.
corona_dict = corona_dict.head(3)
x = corona_dict.index
y = corona_dict['Total'].values

plt.rcParams['figure.figsize'] = (10, 6)
plt.bar(x, y, color=['black', 'grey', 'pink'])
plt.title('Total Confirmed / Deaths / Recovered cases worldwide(until 04/14)')
plt.show()

# %%
# COVID-19 cases with numbers.
# Confirmed : Cumulative number of confirmed cases till that date <br>
# Deaths : Cumulative number of of deaths till that date <br>
# Recovered : Cumulative number of recovered cases till that date <br>

# Let's have a look at difference in the number of the corona cases between 04/14 and 04/13
corona_diff_df = corona_df.groupby(["Date", "Country"])[
    ['Date', 'Country', 'Confirmed']].sum().reset_index()
corona_confirmed_sorted_df = corona_diff_df.sort_values(
    'Country', ascending=False)

# %%
corona_13_df = corona_confirmed_sorted_df[corona_confirmed_sorted_df.Date ==
                                          '04/13/2020'].reset_index().drop('index', axis=1)
corona_14_df = corona_confirmed_sorted_df[corona_confirmed_sorted_df.Date ==
                                          '04/14/2020'].reset_index().drop('index', axis=1)

corona_diff = pd.merge(corona_14_df, corona_13_df, on='Country')
corona_diff['cases_difference_13_14'] = corona_diff['Confirmed_x'] - corona_diff['Confirmed_y']
corona_diff.sort_values('cases_difference_13_14', ascending=False).head(60).style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_d2477_row0_col2, #T_d2477_row0_col4, #T_d2477_row0_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_d2477_row1_col2, #T_d2477_row1_col4 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_d2477_row1_col5 {
#   background-color: #fdccb8;
#   color: #000000;
# }
# #T_d2477_row2_col2, #T_d2477_row3_col5 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_d2477_row2_col4 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_d2477_row2_col5 {
#   background-color: #fedaca;
#   color: #000000;
# }
# #T_d2477_row3_col2 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# #T_d2477_row3_col4 {
#   background-color: #fcb398;
#   color: #000000;
# }
# #T_d2477_row4_col2 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_d2477_row4_col4, #T_d2477_row11_col5, #T_d2477_row12_col5, #T_d2477_row15_col2, #T_d2477_row15_col4 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_d2477_row4_col5 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_d2477_row5_col2 {
#   background-color: #fcb095;
#   color: #000000;
# }
# #T_d2477_row5_col4 {
#   background-color: #fcae92;
#   color: #000000;
# }
# #T_d2477_row5_col5 {
#   background-color: #fee7db;
#   color: #000000;
# }
# #T_d2477_row6_col2, #T_d2477_row6_col4, #T_d2477_row31_col2 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_d2477_row6_col5 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_d2477_row7_col2 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_d2477_row7_col4 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_d2477_row7_col5 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_d2477_row8_col2, #T_d2477_row8_col4, #T_d2477_row9_col5, #T_d2477_row11_col2, #T_d2477_row11_col4, #T_d2477_row31_col4 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_d2477_row8_col5, #T_d2477_row13_col2 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_d2477_row9_col2 {
#   background-color: #fdc5ae;
#   color: #000000;
# }
# #T_d2477_row9_col4 {
#   background-color: #fcc3ab;
#   color: #000000;
# }
# #T_d2477_row10_col2, #T_d2477_row10_col4, #T_d2477_row12_col2, #T_d2477_row12_col4, #T_d2477_row13_col5, #T_d2477_row14_col2, #T_d2477_row14_col4, #T_d2477_row14_col5, #T_d2477_row15_col5, #T_d2477_row16_col2, #T_d2477_row16_col4, #T_d2477_row16_col5, #T_d2477_row17_col2, #T_d2477_row17_col4 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_d2477_row10_col5 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_d2477_row13_col4 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_d2477_row17_col5, #T_d2477_row18_col5, #T_d2477_row19_col5, #T_d2477_row20_col5, #T_d2477_row21_col2, #T_d2477_row21_col4, #T_d2477_row21_col5, #T_d2477_row28_col2, #T_d2477_row28_col4, #T_d2477_row52_col2, #T_d2477_row52_col4 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_d2477_row18_col2, #T_d2477_row18_col4, #T_d2477_row22_col5, #T_d2477_row23_col5, #T_d2477_row24_col2, #T_d2477_row24_col4, #T_d2477_row24_col5, #T_d2477_row25_col5, #T_d2477_row26_col2, #T_d2477_row26_col4, #T_d2477_row26_col5, #T_d2477_row27_col5, #T_d2477_row28_col5, #T_d2477_row29_col5, #T_d2477_row30_col2, #T_d2477_row30_col4, #T_d2477_row30_col5, #T_d2477_row32_col2, #T_d2477_row32_col4, #T_d2477_row36_col2, #T_d2477_row36_col4, #T_d2477_row38_col4, #T_d2477_row58_col2, #T_d2477_row58_col4 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_d2477_row19_col2, #T_d2477_row19_col4, #T_d2477_row20_col2, #T_d2477_row20_col4, #T_d2477_row22_col2, #T_d2477_row22_col4, #T_d2477_row23_col2, #T_d2477_row23_col4, #T_d2477_row25_col2, #T_d2477_row25_col4, #T_d2477_row27_col2, #T_d2477_row27_col4, #T_d2477_row29_col2, #T_d2477_row29_col4, #T_d2477_row31_col5, #T_d2477_row32_col5, #T_d2477_row33_col5, #T_d2477_row34_col5, #T_d2477_row35_col2, #T_d2477_row35_col4, #T_d2477_row35_col5, #T_d2477_row36_col5, #T_d2477_row37_col5, #T_d2477_row38_col2, #T_d2477_row38_col5, #T_d2477_row39_col5, #T_d2477_row40_col5, #T_d2477_row44_col2, #T_d2477_row44_col4, #T_d2477_row46_col2, #T_d2477_row46_col4, #T_d2477_row48_col2, #T_d2477_row48_col4, #T_d2477_row53_col2, #T_d2477_row53_col4 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_d2477_row33_col2, #T_d2477_row33_col4, #T_d2477_row34_col2, #T_d2477_row34_col4, #T_d2477_row39_col2, #T_d2477_row39_col4, #T_d2477_row40_col2, #T_d2477_row40_col4, #T_d2477_row41_col2, #T_d2477_row41_col4, #T_d2477_row41_col5, #T_d2477_row42_col2, #T_d2477_row42_col4, #T_d2477_row42_col5, #T_d2477_row43_col2, #T_d2477_row43_col4, #T_d2477_row43_col5, #T_d2477_row44_col5, #T_d2477_row45_col2, #T_d2477_row45_col4, #T_d2477_row45_col5, #T_d2477_row46_col5, #T_d2477_row47_col2, #T_d2477_row47_col4, #T_d2477_row47_col5, #T_d2477_row48_col5, #T_d2477_row49_col5, #T_d2477_row50_col2, #T_d2477_row50_col4, #T_d2477_row50_col5, #T_d2477_row51_col2, #T_d2477_row51_col4, #T_d2477_row51_col5, #T_d2477_row52_col5, #T_d2477_row53_col5, #T_d2477_row54_col2, #T_d2477_row54_col4, #T_d2477_row54_col5, #T_d2477_row55_col2, #T_d2477_row55_col4, #T_d2477_row55_col5, #T_d2477_row56_col2, #T_d2477_row56_col4, #T_d2477_row56_col5, #T_d2477_row57_col2, #T_d2477_row57_col4, #T_d2477_row57_col5, #T_d2477_row58_col5, #T_d2477_row59_col2, #T_d2477_row59_col4, #T_d2477_row59_col5 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_d2477_row37_col2 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_d2477_row37_col4 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_d2477_row49_col2 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_d2477_row49_col4 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# </style>
# <table id="T_d2477_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Date_x</th>
#       <th class="col_heading level0 col1" >Country</th>
#       <th class="col_heading level0 col2" >Confirmed_x</th>
#       <th class="col_heading level0 col3" >Date_y</th>
#       <th class="col_heading level0 col4" >Confirmed_y</th>
#       <th class="col_heading level0 col5" >cases_difference_13_14</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2477_level0_row0" class="row_heading level0 row0" >12</th>
#       <td id="T_d2477_row0_col0" class="data row0 col0" >04/14/2020</td>
#       <td id="T_d2477_row0_col1" class="data row0 col1" >US</td>
#       <td id="T_d2477_row0_col2" class="data row0 col2" >607670.000000</td>
#       <td id="T_d2477_row0_col3" class="data row0 col3" >04/13/2020</td>
#       <td id="T_d2477_row0_col4" class="data row0 col4" >580619.000000</td>
#       <td id="T_d2477_row0_col5" class="data row0 col5" >27051.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d2477_level0_row1" class="row_heading level0 row1" >13</th>
#       <td id="T_d2477_row1_col0" class="data row1 col0" >04/14/2020</td>
#       <td id="T_d2477_row1_col1" class="data row1 col1" >UK</td>
#       <td id="T_d2477_row1_col2" class="data row1 col2" >94845.000000</td>
#       <td id="T_d2477_row1_col3" class="data row1 col3" >04/13/2020</td>
#       <td id="T_d2477_row1_col4" class="data row1 col4" >89570.000000</td>
#       <td id="T_d2477_row1_col5" class="data row1 col5" >5275.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d2477_level0_row2" class="row_heading level0 row2" >14</th>
#       <td id="T_d2477_row2_col0" class="data row2 col0" >04/14/2020</td>
#       <td id="T_d2477_row2_col1" class="data row2 col1" >Turkey</td>
#       <td id="T_d2477_row2_col2" class="data row2 col2" >65111.000000</td>
#       <td id="T_d2477_row2_col3" class="data row2 col3" >04/13/2020</td>
#       <td id="T_d2477_row2_col4" class="data row2 col4" >61049.000000</td>
#       <td id="T_d2477_row2_col5" class="data row2 col5" >4062.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d2477_level0_row3" class="row_heading level0 row3" >103</th>
#       <td id="T_d2477_row3_col0" class="data row3 col0" >04/14/2020</td>
#       <td id="T_d2477_row3_col1" class="data row3 col1" >Italy</td>
#       <td id="T_d2477_row3_col2" class="data row3 col2" >162488.000000</td>
#       <td id="T_d2477_row3_col3" class="data row3 col3" >04/13/2020</td>
#       <td id="T_d2477_row3_col4" class="data row3 col

# %%
# Top 10  infected Countries
sorted_By_Confirmed1 = corona_sorted_df.sort_values(
    'Confirmed', ascending=False)
sorted_By_Confirmed1 = sorted_By_Confirmed1.head(10)
x = sorted_By_Confirmed1.Country
y = sorted_By_Confirmed1.Confirmed
plt.rcParams['figure.figsize'] = (12, 10)
plt.bar(x, y, color=(0.2, 0.4, 0.6, 0.6))
plt.title('Top 10 infected countries(until 04/14)')
plt.show()

# %%
corona_cases_per_day = corona_df.groupby(
    ["Date"])['Confirmed', 'Deaths', 'Recovered'].sum().reset_index()
sorted_By_Confirmed1 = corona_cases_per_day.sort_values(
    'Date', ascending=False)

sorted_By_Confirmed1.style.background_gradient(cmap='Reds')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# <style type="text/css">
# #T_5c134_row0_col1, #T_5c134_row0_col2, #T_5c134_row0_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_5c134_row1_col1 {
#   background-color: #75030f;
#   color: #f1f1f1;
# }
# #T_5c134_row1_col2, #T_5c134_row1_col3 {
#   background-color: #800610;
#   color: #f1f1f1;
# }
# #T_5c134_row2_col1 {
#   background-color: #860811;
#   color: #f1f1f1;
# }
# #T_5c134_row2_col2 {
#   background-color: #960b13;
#   color: #f1f1f1;
# }
# #T_5c134_row2_col3 {
#   background-color: #9d0d14;
#   color: #f1f1f1;
# }
# #T_5c134_row3_col1 {
#   background-color: #9a0c14;
#   color: #f1f1f1;
# }
# #T_5c134_row3_col2 {
#   background-color: #a91016;
#   color: #f1f1f1;
# }
# #T_5c134_row3_col3 {
#   background-color: #ac1117;
#   color: #f1f1f1;
# }
# #T_5c134_row4_col1 {
#   background-color: #aa1016;
#   color: #f1f1f1;
# }
# #T_5c134_row4_col2 {
#   background-color: #b71319;
#   color: #f1f1f1;
# }
# #T_5c134_row4_col3 {
#   background-color: #bd151a;
#   color: #f1f1f1;
# }
# #T_5c134_row5_col1 {
#   background-color: #b91419;
#   color: #f1f1f1;
# }
# #T_5c134_row5_col2 {
#   background-color: #c9181d;
#   color: #f1f1f1;
# }
# #T_5c134_row5_col3 {
#   background-color: #cb181d;
#   color: #f1f1f1;
# }
# #T_5c134_row6_col1 {
#   background-color: #c7171c;
#   color: #f1f1f1;
# }
# #T_5c134_row6_col2 {
#   background-color: #d92523;
#   color: #f1f1f1;
# }
# #T_5c134_row6_col3 {
#   background-color: #db2824;
#   color: #f1f1f1;
# }
# #T_5c134_row7_col1 {
#   background-color: #d32020;
#   color: #f1f1f1;
# }
# #T_5c134_row7_col2 {
#   background-color: #e83429;
#   color: #f1f1f1;
# }
# #T_5c134_row7_col3 {
#   background-color: #ed392b;
#   color: #f1f1f1;
# }
# #T_5c134_row8_col1 {
#   background-color: #de2b25;
#   color: #f1f1f1;
# }
# #T_5c134_row8_col2 {
#   background-color: #f24734;
#   color: #f1f1f1;
# }
# #T_5c134_row8_col3 {
#   background-color: #f34a36;
#   color: #f1f1f1;
# }
# #T_5c134_row9_col1 {
#   background-color: #ea362a;
#   color: #f1f1f1;
# }
# #T_5c134_row9_col2, #T_5c134_row9_col3 {
#   background-color: #f6583e;
#   color: #f1f1f1;
# }
# #T_5c134_row10_col1 {
#   background-color: #f14130;
#   color: #f1f1f1;
# }
# #T_5c134_row10_col2, #T_5c134_row12_col1 {
#   background-color: #fa6547;
#   color: #f1f1f1;
# }
# #T_5c134_row10_col3 {
#   background-color: #f96346;
#   color: #f1f1f1;
# }
# #T_5c134_row11_col1 {
#   background-color: #f6563d;
#   color: #f1f1f1;
# }
# #T_5c134_row11_col2 {
#   background-color: #fb7555;
#   color: #f1f1f1;
# }
# #T_5c134_row11_col3 {
#   background-color: #fb7252;
#   color: #f1f1f1;
# }
# #T_5c134_row12_col2 {
#   background-color: #fc8464;
#   color: #f1f1f1;
# }
# #T_5c134_row12_col3 {
#   background-color: #fb7c5c;
#   color: #f1f1f1;
# }
# #T_5c134_row13_col1 {
#   background-color: #fb7353;
#   color: #f1f1f1;
# }
# #T_5c134_row13_col2 {
#   background-color: #fc9373;
#   color: #000000;
# }
# #T_5c134_row13_col3 {
#   background-color: #fc8767;
#   color: #f1f1f1;
# }
# #T_5c134_row14_col1 {
#   background-color: #fc7f5f;
#   color: #f1f1f1;
# }
# #T_5c134_row14_col2, #T_5c134_row17_col1 {
#   background-color: #fca082;
#   color: #000000;
# }
# #T_5c134_row14_col3 {
#   background-color: #fc9272;
#   color: #000000;
# }
# #T_5c134_row15_col1 {
#   background-color: #fc8b6b;
#   color: #f1f1f1;
# }
# #T_5c134_row15_col2, #T_5c134_row18_col1 {
#   background-color: #fcab8f;
#   color: #000000;
# }
# #T_5c134_row15_col3 {
#   background-color: #fc9c7d;
#   color: #000000;
# }
# #T_5c134_row16_col1 {
#   background-color: #fc9576;
#   color: #000000;
# }
# #T_5c134_row16_col2, #T_5c134_row19_col1 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# #T_5c134_row16_col3 {
#   background-color: #fca689;
#   color: #000000;
# }
# #T_5c134_row17_col2 {
#   background-color: #fcbda4;
#   color: #000000;
# }
# #T_5c134_row17_col3 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_5c134_row18_col2 {
#   background-color: #fdc5ae;
#   color: #000000;
# }
# #T_5c134_row18_col3 {
#   background-color: #fcb398;
#   color: #000000;
# }
# #T_5c134_row19_col2, #T_5c134_row22_col1 {
#   background-color: #fdcdb9;
#   color: #000000;
# }
# #T_5c134_row19_col3 {
#   background-color: #fcb99f;
#   color: #000000;
# }
# #T_5c134_row20_col1 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_5c134_row20_col2, #T_5c134_row23_col1, #T_5c134_row28_col3 {
#   background-color: #fdd3c1;
#   color: #000000;
# }
# #T_5c134_row20_col3 {
#   background-color: #fcbea5;
#   color: #000000;
# }
# #T_5c134_row21_col1, #T_5c134_row22_col3 {
#   background-color: #fdc6b0;
#   color: #000000;
# }
# #T_5c134_row21_col2, #T_5c134_row32_col3 {
#   background-color: #fedaca;
#   color: #000000;
# }
# #T_5c134_row21_col3 {
#   background-color: #fcc2aa;
#   color: #000000;
# }
# #T_5c134_row22_col2, #T_5c134_row36_col3 {
#   background-color: #fedfd0;
#   color: #000000;
# }
# #T_5c134_row23_col2, #T_5c134_row40_col3 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_5c134_row23_col3 {
#   background-color: #fdc9b3;
#   color: #000000;
# }
# #T_5c134_row24_col1, #T_5c134_row31_col3 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_5c134_row24_col2, #T_5c134_row42_col3 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_5c134_row24_col3 {
#   background-color: #fdccb8;
#   color: #000000;
# }
# #T_5c134_row25_col1 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_5c134_row25_col2 {
#   background-color: #fee7db;
#   color: #000000;
# }
# #T_5c134_row25_col3 {
#   background-color: #fdcebb;
#   color: #000000;
# }
# #T_5c134_row26_col1, #T_5c134_row38_col3 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_5c134_row26_col2, #T_5c134_row31_col1 {
#   background-color: #fee8dd;
#   color: #000000;
# }
# #T_5c134_row26_col3 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_5c134_row27_col1, #T_5c134_row41_col3 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_5c134_row27_col2, #T_5c134_row47_col3 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_5c134_row27_col3 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_5c134_row28_col1 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_5c134_row28_col2, #T_5c134_row33_col1, #T_5c134_row34_col1, #T_5c134_row48_col3 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_5c134_row29_col1, #T_5c134_row44_col3 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_5c134_row29_col2, #T_5c134_row36_col1, #T_5c134_row37_col1 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_5c134_row29_col3 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_5c134_row30_col1, #T_5c134_row45_col3 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_5c134_row30_col2, #T_5c134_row38_col1, #T_5c134_row39_col1, #T_5c134_row50_col3 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_5c134_row30_col3 {
#   background-color: #fdd5c4;
#   color: #000000;
# }
# #T_5c134_row31_col2, #T_5c134_row42_col1, #T_5c134_row43_col1, #T_5c134_row44_col1, #T_5c134_row45_col1 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_5c134_row32_col1 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_5c134_row32_col2, #T_5c134_row46_col1, #T_5c134_row47_col1, #T_5c134_row48_col1, #T_5c134_row49_col1, #T_5c134_row50_col1, #T_5c134_row51_col1, #T_5c134_row52_col1, #T_5c134_row53_col3 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_5c134_row33_col2, #T_5c134_row34_col2, #T_5c134_row53_col1, #T_5c134_row54_col1, #T_5c134_row54_col3, #T_5c134_row55_col1, #T_5c134_row56_col1, #T_5c134_row57_col1, #T_5c134_row58_col1 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_5c134_row33_col3, #T_5c134_row34_col3 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_5c134_row35_col1, #T_5c134_row49_col3 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_5c134_row35_col2, #T_5c134_row36_col2, #T_5c134_row55_col3, #T_5c134_row59_col1, #T_5c134_row60_col1 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_5c134_row35_col3 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_5c134_row37_col2, #T_5c134_row38_col2, #T_5c134_row56_col3, #T_5c134_row61_col1 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_5c134_row37_col3 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_5c134_row39_col2, #T_5c134_row40_col2, #T_5c134_row41_col2, #T_5c134_row42_col2, #T_5c134_row43_col2, #T_5c134_row44_col2, #T_5c134_row57_col3 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_5c134_row39_col3 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_5c134_row40_co

# %%
# Line graph that illustrates increasing infections cases per day.
x = corona_cases_per_day.Date
y = corona_cases_per_day.Confirmed
y1 = corona_cases_per_day.Deaths
y2 = corona_cases_per_day.Recovered
ax = plt.gca()
corona_cases_per_day.plot(kind='line', x='Date',
                          y='Confirmed', color='blue', ax=ax)
corona_cases_per_day.plot(kind='line', x='Date',
          y='Deaths', color='red', ax=ax)
corona_cases_per_day.plot(kind='line', x='Date',
                          y='Recovered', color='green', ax=ax)

plt.ylabel('Total cases(#)')
plt.title('Total confirmed, death and recovered case report per day.')
plt.show()

# %%
# Now, Let's prepare the data for the prediction.
# I am converting Date column of dataset to numeric for ensuring the independent variable should be on the same scale as other.
# In the date, I assume the start date as 0 (first day) when the COVID-19 had started and increasing by 1 over increament in date.
# Splitting corona data into Date and confirmed cases.
corona_index_df = pd.DataFrame(corona_cases_per_day.index)
corona_confirmed_df = pd.DataFrame(corona_cases_per_day.Confirmed)
corona_recovered_df = pd.DataFrame(corona_cases_per_day.Recovered)
corona_death_df = pd.DataFrame(corona_cases_per_day.Deaths)

# %%
####################################
## Prepare dataset for model      ##
###################################

# Splitting the data.
# Here, I am preparing the train, validate and test dataset.
# Using 90% of the data to train the model.
x_days_train = corona_index_df[0:78]
x_days_validate = corona_index_df[78:82]
x_days_test = corona_index_df[82:84]

# Confirmed
y_confirmed_train = corona_confirmed_df[0:78]
y_confirmed_validate = corona_confirmed_df[78:82]
y_confirmed_test = corona_confirmed_df[82:84]

# %%
####################################
##  Regression Model             ##
###################################

# Let's apply Linear regression model on the dataset. As I can see, all the data are continuous, I think that Linear regression will be perfect.
# Linear regression
ln_model = LinearRegression()
ln_model.fit(x_days_train, y_confirmed_train)
y_pred = pd.DataFrame(ln_model.predict(x_days_train))
print(type(y_pred))
print(type(x_days_train[0]))
x_days_train[0]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4
#       ..
# 73    73
# 74    74
# 75    75
# 76    76
# 77    77
# Name: 0, Length: 78, dtype: int64

# %%
plt.scatter(x_days_train, y_confirmed_train, color='red')

plt.plot(x_days_train[0], ln_model.predict(x_days_train), color='blue')
plt.title('COVID-19 confimed cases of worldwide(Linear Regression)')
plt.xlabel('Days')
plt.ylabel('Confirmed(#)')
plt.show()

# %%
# # After applying the linear regression, I can see the predicted line do not fit with the independent variables.
# # It means that the line is unable to capture the patterns in the data.This may be an example of under-fitting.
# # For confirmation, lets check the rmse and r2 score for the model.
print('Linear Regession  R2 Score: ',r2_score(y_confirmed_train, ln_model.predict(x_days_train)))
rmse = np.sqrt(mean_squared_error(y_confirmed_train, ln_model.predict(x_days_train)))
print('RMSE of Linear regression is :', rmse)
# Out:
# Linear Regession  R2 Score:  0.6130655652167281
# RMSE of Linear regression is : 235634.93702958743

# %%
# R2 score is 63%. It means that 63% of variance is covered by the model.
# Now, to overcome the under-fitting problem, I have to increase the complexity of the model.
# Here, I have used Polynomial linear regression technique because it best fit for the prediction of how deceases spread accross the territory or the world.
# Polynomial linear regression to predict future confirmed cases.

# %%
# Polynomal linear Regression (degree=10)
poly_reg = PolynomialFeatures(degree=10)
# Model training with the train data.
x_poly = poly_reg.fit_transform(x_days_train)
# Applying linear regression.
lin_reg = LinearRegression()
lin_reg.fit(x_poly, y_confirmed_train)
# Out:
# LinearRegression()

# %%
# Graphical summary of the model.
plt.scatter(x_days_train, y_confirmed_train, color='red')
plt.plot(x_days_train[0], lin_reg.predict(poly_reg.fit_transform(x_days_train)), color='blue')
plt.title("COVID-19 confimed cases of worldwide(Polynomial Regression Model)")
plt.xlabel('Days')
plt.ylabel('Total confirmed cases(#)')
plt.show()

# %%
# It seems that the polynomial line connects all the dots.
# Now, let's validate the model with the x_days_validate which contains index. For the index, the model
# will predict the confirmed cases of the data.
y_pred = lin_reg.predict(poly_reg.fit_transform(x_days_validate))
result = pd.DataFrame(y_pred)
result['Real Value'] = y_confirmed_validate.iloc[:, :].values
result['Predicted Value'] = pd.DataFrame(y_pred)
result = result[['Real Value', 'Predicted Value']]
print(result)
# Out:
#    Real Value  Predicted Value
# 0   1595350.0     1.586622e+06
# 1   1691719.0     1.662186e+06
# 2   1771514.0     1.736674e+06
# 3   1846680.0     1.811466e+06

# %%
# Now, as per the model,let's check the accuracy of the model on validate data set.
print('Polynomial Regession  R2 Score   : ',
      r2_score(y_confirmed_validate, y_pred))
rmse = np.sqrt(mean_squared_error(y_confirmed_validate, y_pred))
print('RMSE of polynomial regression is :', rmse)
# Out:
# Polynomial Regession  R2 Score   :  0.9024569832922948
# RMSE of polynomial regression is : 29164.36880060237

# %%
# However, let's apply the accurate model for test data.
y_confirmed_test_pred = lin_reg.predict(poly_reg.fit_transform(x_days_test))
predicted_result = pd.DataFrame(y_confirmed_test_pred)
predicted_result['Real Test Value'] = y_confirmed_test.iloc[:, :].values
predicted_result['Predicted Test Value'] = pd.DataFrame(y_confirmed_test_pred)
predicted_result = predicted_result[[
    'Real Test Value', 'Predicted Test Value']]
print(predicted_result)
# Out:
#    Real Test Value  Predicted Test Value
# 0        1917320.0          1.888829e+06
# 1        1976192.0          1.972149e+06
